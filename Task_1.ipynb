# %%
import pandas as pd

df = pd.read_csv("task1.csv")
df.head()
# Out:
#              Id        AB          AF          AH         AM        AR  \
# 0  000ff2bfdfe9  0.209377  3109.03329   85.200147  22.394407  8.138688
# 1  007255e47698  0.145282   978.76416   85.200147  36.968889  8.138688
# 2  013f2bd269f5  0.470030  2635.10654   85.200147  32.360553  8.138688
# 3  043ac50845d5  0.252107  3819.65177  120.201618  77.112203  8.138688
# 4  044fb8a146ec  0.380297  3733.04844   85.200147  14.103738  8.138688
#
#          AX        AY         AZ          BC  ...        FL        FR  \
# 0  0.699861  0.025578   9.812214    5.555634  ...  7.298162   1.73855
# 1  3.632190  0.025578  13.517790    1.229900  ...  0.173229   0.49706
# 2  6.732840  0.025578  12.824570    1.229900  ...  7.709560   0.97556
# 3  3.685344  0.025578  11.053708    1.229900  ...  6.122162   0.49706
# 4  3.942255  0.054810   3.396778  102.151980  ...  8.153058  48.50134
#
#          FS         GB          GE            GF         GH         GI  \
# ...

# %% [markdown]
# ### 1. Explotary Data Analysis

# %%
df.shape
# Out:
# (617, 58)

# %%
df.describe()
# Out:
#                AB            AF           AH          AM          AR  \
# count  617.000000    617.000000   617.000000  617.000000  617.000000
# mean     0.477149   3502.013221   118.624513   38.968552   10.128242
# std      0.468388   2300.322717   127.838950   69.728226   10.518877
# min      0.081187    192.593280    85.200147    3.177522    8.138688
# 25%      0.252107   2197.345480    85.200147   12.270314    8.138688
# 50%      0.354659   3120.318960    85.200147   20.533110    8.138688
# 75%      0.559763   4361.637390   113.739540   39.139886    8.138688
# max      6.161666  28688.187660  1910.123198  630.518230  178.943634
#
#                AX          AY          AZ           BC           BD   ...  \
# count  617.000000  617.000000  617.000000   617.000000    617.000000  ...
# mean     5.545576    0.060320   10.566447     8.053012   5350.388655  ...
# std      2.551696    0.416817    4.350645    65.166943   3021.326641  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 58 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      617 non-null    object
#  1   AB      617 non-null    float64
#  2   AF      617 non-null    float64
#  3   AH      617 non-null    float64
#  4   AM      617 non-null    float64
#  5   AR      617 non-null    float64
#  6   AX      617 non-null    float64
#  7   AY      617 non-null    float64
#  8   AZ      617 non-null    float64
#  9   BC      617 non-null    float64
#  10  BD      617 non-null    float64
#  11  BN      617 non-null    float64
#  12  BP      617 non-null    float64
#  13  BQ      557 non-null    float64
#  14  BR      617 non-null    float64
#  15  BZ      617 non-null    float64
#  16  CB      615 non-null    float64
#  17  CC      614 non-null    float64
#  18  CD      617 non-null    float64
#  19  CF      617 non-null    float64
# ...

# %%
import matplotlib.pyplot as plt

# visualize the numerical columns
df.hist(bins=20, figsize=(12,20))
plt.show()

# %%
import numpy as np

# corrleation of numerical features with the target
df_numeric = df.select_dtypes(include=[np.number])
corr_matrix = df_numeric.corr()
corr_matrix["Class"].sort_values(ascending=False)
# Out:
# Class    1.000000
# AF       0.302638
# BQ       0.281257
# AB       0.280612
# DU       0.261000
# DI       0.260760
# FL       0.244185
# AM       0.239170
# FE       0.216359
# BN       0.198283
# EH       0.179855
# CD       0.171304
# BP       0.157286
# BC       0.155882
# FD       0.131100
# BZ       0.112423
# BD       0.112184
# CF       0.109748
# FR       0.104099
# AX       0.097616
# BR       0.088554
# EB       0.088005
# GB       0.083343
# AY       0.082420
# GI       0.076894
# EL       0.067947
# AR       0.064380
# DF       0.064272
# DY       0.062734
# AH       0.044645
# GH       0.033540
# FC       0.030689
# CL       0.016852
# DV       0.015477
# AZ       0.013516
# CH       0.008144
# FS       0.001139
# DN      -0.008478
# CB      -0.014777
# EG      -0.024610
# EU      -0.039739
# CS      -0.047438
# CC      -0.054723
# CW      -0.062639
# EP      -0.068383
# GE      -0.070766
# CU      -0.083185
# FI      -0.094327
# GL      -0.119202
# DE      -0.124977
# ...

# %% [markdown]
# ### Report: Some of the feature are negatively correlated with the class and some has no correlation. Such features do not contribute meaningful information to the predictive power of the model and can introduce noise, leading to overfitting and decreased generalizability. By dropping these irrelevant features, we can reduce the complexity of the model, improve its training efficiency.

# %%
# Categorical attributes exploration
df['EJ'].describe()
# Out:
# count     617
# unique      2
# top         B
# freq      395
# Name: EJ, dtype: object

# %%
df["EJ"].value_counts()
# Out:
# EJ
# B    395
# A    222
# Name: count, dtype: int64

# %%
dummies = pd.get_dummies(df["EJ"], prefix="EJ")
df = pd.concat([df, dummies], axis=1)

# %%
df["EJ_A"] = df["EJ_A"].astype('float64')
df["EJ_B"] = df["EJ_B"].astype('float64')

df_numeric = df.select_dtypes(include=[np.number])
corr_matrix = df_numeric.corr()
corr_matrix["Class"].sort_values(ascending=False)
# Out:
# Class    1.000000
# AF       0.302638
# BQ       0.281257
# AB       0.280612
# DU       0.261000
# DI       0.260760
# FL       0.244185
# AM       0.239170
# FE       0.216359
# BN       0.198283
# EH       0.179855
# CD       0.171304
# BP       0.157286
# BC       0.155882
# FD       0.131100
# BZ       0.112423
# BD       0.112184
# CF       0.109748
# FR       0.104099
# AX       0.097616
# EJ_B     0.096500
# BR       0.088554
# EB       0.088005
# GB       0.083343
# AY       0.082420
# GI       0.076894
# EL       0.067947
# AR       0.064380
# DF       0.064272
# DY       0.062734
# AH       0.044645
# GH       0.033540
# FC       0.030689
# CL       0.016852
# DV       0.015477
# AZ       0.013516
# CH       0.008144
# FS       0.001139
# DN      -0.008478
# CB      -0.014777
# EG      -0.024610
# EU      -0.039739
# CS      -0.047438
# CC      -0.054723
# CW      -0.062639
# EP      -0.068383
# GE      -0.070766
# CU      -0.083185
# FI      -0.094327
# EJ_A    -0.096500
# ...

# %%
df["EJ"] = df["EJ"].map({
    "A":0,
    "B":1
})
df["EJ"] = df["EJ"].astype('float64')

# %%
df_numeric = df.select_dtypes(include=[np.number])
corr_matrix = df_numeric.corr()
corr_matrix["Class"].sort_values(ascending=False)
# Out:
# Class    1.000000
# AF       0.302638
# BQ       0.281257
# AB       0.280612
# DU       0.261000
# DI       0.260760
# FL       0.244185
# AM       0.239170
# FE       0.216359
# BN       0.198283
# EH       0.179855
# CD       0.171304
# BP       0.157286
# BC       0.155882
# FD       0.131100
# BZ       0.112423
# BD       0.112184
# CF       0.109748
# FR       0.104099
# AX       0.097616
# EJ       0.096500
# EJ_B     0.096500
# BR       0.088554
# EB       0.088005
# GB       0.083343
# AY       0.082420
# GI       0.076894
# EL       0.067947
# AR       0.064380
# DF       0.064272
# DY       0.062734
# AH       0.044645
# GH       0.033540
# FC       0.030689
# CL       0.016852
# DV       0.015477
# AZ       0.013516
# CH       0.008144
# FS       0.001139
# DN      -0.008478
# CB      -0.014777
# EG      -0.024610
# EU      -0.039739
# CS      -0.047438
# CC      -0.054723
# CW      -0.062639
# EP      -0.068383
# GE      -0.070766
# CU      -0.083185
# FI      -0.094327
# ...

# %% [markdown]
# ### Report: Since the EJ column provides a straightforward interpretation of its impact on the target variable. Keeping EJ simplifies the dataset by retaining essential information while avoiding duplication found in EJ_A and EJ_B, which serve the same purpose but split into two variables unnecessarily.

# %%
df = df.drop(columns=["Id", "EJ_A", "EJ_B"]) # since id column is irrelevant in this case

# %%
df.isna().sum()
# Out:
# AB        0
# AF        0
# AH        0
# AM        0
# AR        0
# AX        0
# AY        0
# AZ        0
# BC        0
# BD        0
# BN        0
# BP        0
# BQ       60
# BR        0
# BZ        0
# CB        2
# CC        3
# CD        0
# CF        0
# CH        0
# CL        0
# CR        0
# CS        0
# CU        0
# CW        0
# DA        0
# DE        0
# DF        0
# DH        0
# DI        0
# DL        0
# DN        0
# DU        1
# DV        0
# DY        0
# EB        0
# EE        0
# EG        0
# EH        0
# EJ        0
# EL       60
# EP        0
# EU        0
# FC        1
# FD        0
# FE        0
# FI        0
# FL        1
# FR        0
# FS        2
# GB        0
# GE        0
# GF        0
# GH        0
# GI        0
# GL        1
# Class     0
# dtype: int64

# %%
# two column has higher missing, imputing these column can lead to poor results
df = df.drop(columns=['BQ','EL'])
lower_missing_values_cols = [ 'CB', 'CC', 'DU', 'FC', 'FL', 'FS', 'GL']
df[lower_missing_values_cols] = df[lower_missing_values_cols].fillna(df[lower_missing_values_cols].median())

# %%
# keeping only the higher correlated features

corr_threshold = 0.1
target_corr_abs = df.corr()['Class'].abs()

selected_features = target_corr_abs[target_corr_abs >= corr_threshold].index
df_selected = df[selected_features]
print("Selected features based on correlation threshold:", selected_features)
print("Shape of DataFrame after feature selection:", df_selected.shape)
# Out:
# Selected features based on correlation threshold: Index(['AB', 'AF', 'AM', 'BC', 'BD ', 'BN', 'BP', 'BZ', 'CD ', 'CF', 'CR',
#        'DA', 'DE', 'DH', 'DI', 'DL', 'DU', 'EE', 'EH', 'FD ', 'FE', 'FL', 'FR',
#        'GF', 'GL', 'Class'],
#       dtype='object')
# Shape of DataFrame after feature selection: (617, 26)

# %%
df_selected.describe()
# Out:
#                AB            AF          AM           BC           BD   \
# count  617.000000    617.000000  617.000000   617.000000    617.000000
# mean     0.477149   3502.013221   38.968552     8.053012   5350.388655
# std      0.468388   2300.322717   69.728226    65.166943   3021.326641
# min      0.081187    192.593280    3.177522     1.229900   1693.624320
# 25%      0.252107   2197.345480   12.270314     1.229900   4155.702870
# 50%      0.354659   3120.318960   20.533110     1.229900   4997.960730
# 75%      0.559763   4361.637390   39.139886     5.081244   6035.885700
# max      6.161666  28688.187660  630.518230  1463.693448  53060.599240
#
#                BN           BP            BZ         CD           CF  ...  \
# count  617.000000   617.000000    617.000000  617.000000  617.000000  ...
# mean    21.419492   231.322223    550.632525   90.251735   11.241064  ...
# std      3.478278   183.992505   2076.371275   51.585130   13.571133  ...
# ...

# %%
df_selected.head()
# Out:
#          AB          AF         AM          BC         BD        BN  \
# 0  0.209377  3109.03329  22.394407    5.555634  4126.58731  22.5984
# 1  0.145282   978.76416  36.968889    1.229900  5496.92824  19.4205
# 2  0.470030  2635.10654  32.360553    1.229900  5135.78024  26.4825
# 3  0.252107  3819.65177  77.112203    1.229900  4169.67738  23.6577
# 4  0.380297  3733.04844  14.103738  102.151980  5728.73412  24.0108
#
#            BP          BZ        CD          CF  ...        DU        EE  \
# 0  175.638726  257.432377  23.387600   4.851915  ...  5.310690  1.987283
# 1  155.868030  257.432377  50.628208   6.085041  ...  0.005518  0.858603
# 2  128.988531  257.432377  85.955376   5.376488  ...  1.289739  8.146651
# 3  237.282264  257.432377  88.159360   2.347652  ...  2.655345  3.813326
# 4  324.546318  257.432377  72.644264  30.537722  ...  1.144902  3.490846
#
#          EH        FD             FE        FL        FR            GF  \
# ...

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AB      617 non-null    float64
#  1   AF      617 non-null    float64
#  2   AM      617 non-null    float64
#  3   BC      617 non-null    float64
#  4   BD      617 non-null    float64
#  5   BN      617 non-null    float64
#  6   BP      617 non-null    float64
#  7   BZ      617 non-null    float64
#  8   CD      617 non-null    float64
#  9   CF      617 non-null    float64
#  10  CR      617 non-null    float64
#  11  DA      617 non-null    float64
#  12  DE      617 non-null    float64
#  13  DH      617 non-null    float64
#  14  DI      617 non-null    float64
#  15  DL      617 non-null    float64
#  16  DU      617 non-null    float64
#  17  EE      617 non-null    float64
#  18  EH      617 non-null    float64
#  19  FD      617 non-null    float64
# ...

# %%
X = df_selected.drop(columns=["Class"], axis=1)
y = df_selected["Class"].copy()

# %% [markdown]
# ### 2 Apply t-SNE algorithms

# %%
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
import seaborn as sn

standardized_df = StandardScaler().fit_transform(X)

model = TSNE(n_components = 2, random_state = 42)
 
tsne_data = model.fit_transform(X)
tsne_data = np.vstack((tsne_data.T, y)).T
tsne_df = pd.DataFrame(data = tsne_data, columns =("Dim_1", "Dim_2", "label"))
 
sn.scatterplot(data=tsne_df, x='Dim_1', y='Dim_2', hue='label', palette="bright")
plt.show()

# %% [markdown]
# ### 3. Apply ML algorithms

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.15, stratify=y, random_state=42)
print(X_train.shape)
print(X_valid.shape)
# Out:
# (524, 25)
# (93, 25)

# %%
# cross-validation function
from sklearn.model_selection import cross_val_score

def my_cross_validation(clf):
    print(cross_val_score(clf, X_train, y_train, cv=5, scoring='accuracy').mean())

# %%
# Random forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline

rnd_clf = make_pipeline(
    StandardScaler(),
    RandomForestClassifier(n_estimators=500, max_leaf_nodes=20, n_jobs=-1, random_state=42)
)
my_cross_validation(rnd_clf)
# Out:
# 0.9026556776556778

# %%
# SGD classifier
from sklearn.linear_model import SGDClassifier

sgd_clf = make_pipeline(
    StandardScaler(),
    SGDClassifier(loss="log_loss", alpha=0.01, max_iter=500, n_jobs=-1, random_state=42, learning_rate='adaptive', eta0=0.1, 
                  early_stopping=True, n_iter_no_change=10, warm_start=True)
)

sgd_clf.fit(X_train, y_train)
my_cross_validation(sgd_clf)
# Out:
# 0.8854761904761904

# %%
# StackingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

stacking_clf = make_pipeline(
    StandardScaler(),
    StackingClassifier(
        estimators=[
            ('sgd', SGDClassifier(loss="log_loss",  max_iter=500, n_jobs=-1, random_state=42, learning_rate='adaptive', eta0=0.1, 
                  early_stopping=True, n_iter_no_change=10)),
            ('lr', LogisticRegression(C=0.1, random_state=42, n_jobs=-1)),
            ('dt', DecisionTreeClassifier(max_depth=10, min_samples_leaf=5, max_features="log2", random_state=42))
        ],
        final_estimator= RandomForestClassifier(n_estimators=500, max_leaf_nodes=20, n_jobs=-1, random_state=42),
        cv= 3
    )
)
my_cross_validation(stacking_clf)
# Out:
# 0.8817216117216118

# %%
# Precision vs Recall Curve
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import cross_val_predict

def my_precision_vs_recall_curves(clfs, clf_labels):
    plt.figure(figsize=(10, 5))

    for clf, label in zip(clfs, clf_labels):
        y_score = cross_val_predict(clf, X_train, y_train, cv=3, method="predict_proba")[:, 1]
        precision, recall, _ = precision_recall_curve(y_train, y_score)
        plt.plot(precision, recall, label=label, linewidth=2, linestyle='solid')

    plt.title("Precision vs Recall Curves")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.legend()
    plt.show()

# %%
clfs = [sgd_clf,rnd_clf, stacking_clf]
clf_labels = ["SGDClassifier","Random Forest Classifier", "Stacking Classifier"]
my_precision_vs_recall_curves(clfs, clf_labels)

# %%
# Random forest performed better than other classifier, let'see the classification report
from sklearn.metrics import classification_report

def my_classification_report_on_train_data(clf):
    y_train_pred = cross_val_predict(clf, X_train, y_train, cv=5)
    cr = classification_report(y_train, y_train_pred)
    print(cr)

my_classification_report_on_train_data(rnd_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       432
#            1       0.80      0.60      0.68        92
#
#     accuracy                           0.90       524
#    macro avg       0.86      0.78      0.81       524
# weighted avg       0.90      0.90      0.90       524

# %% [markdown]
# #### There is room for improvement in correctly identifying instances of class 1 (lower recall), suggesting potential adjustments in the model to better capture true positives.

# %%
## Fine-tuning the model with randomized search
from sklearn.pipeline import Pipeline
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

# preprocessing steps
preprocessing = make_column_transformer(
    (StandardScaler(), make_column_selector(dtype_include=np.number))
)

# Define the full pipeline with preprocessing
full_pipeline_rf = Pipeline([
    ("preprocessing", preprocessing),
    ("rf_clf", RandomForestClassifier(random_state=42))
])

# Define hyperparameter distributions
param_distributions_rf = {
    'rf_clf__n_estimators': randint(low=50, high=200),
    'rf_clf__max_depth': randint(low=5, high=20),
    'rf_clf__min_samples_split': randint(low=2, high=20),
    'rf_clf__min_samples_leaf': randint(low=1, high=10),
    'rf_clf__max_features': ['sqrt', 'log2']
}


rnd_search_rf = RandomizedSearchCV(
    full_pipeline_rf, param_distributions=param_distributions_rf, n_iter=20, cv=3, 
    scoring='accuracy', random_state=42, verbose=1, n_jobs=-1
)
rnd_search_rf.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(transformers=[('standardscaler',
#                                                                                StandardScaler(),
#                                                                                <sklearn.compose._column_transformer.make_column_selector object at 0x14c953710>)])),
#                                              ('rf_clf',
#                                               RandomForestClassifier(random_state=42))]),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'rf_clf__max_depth': <scipy.stats._distn_...
#                                                                  'log2'],
# ...

# %%
print("Best Parameters:", rnd_search_rf.best_params_)
print("Best Score:", rnd_search_rf.best_score_)
# Out:
# Best Parameters: {'rf_clf__max_depth': 19, 'rf_clf__max_features': 'sqrt', 'rf_clf__min_samples_leaf': 1, 'rf_clf__min_samples_split': 5, 'rf_clf__n_estimators': 99}
# Best Score: 0.9121839080459769

# %%
# let's define the final model
final_model = rnd_search_rf.best_estimator_
final_model
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('standardscaler',
#                                                   StandardScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x14c952510>)])),
#                 ('rf_clf',
#                  RandomForestClassifier(max_depth=19, min_samples_split=5,
#                                         n_estimators=99, random_state=42))])

# %%
# model evaluation on validation data
y_pred = final_model.predict(X_valid)
cr = classification_report(y_valid, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94        77
#            1       0.89      0.50      0.64        16
#
#     accuracy                           0.90        93
#    macro avg       0.90      0.74      0.79        93
# weighted avg       0.90      0.90      0.89        93

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_valid, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Class 0', 'Class 1'])
disp.plot(cmap='Blues', values_format='d')  # 'd' for integer formatting

plt.title('Confusion Matrix')
plt.show()

# %%
# saving the model using joblib
import joblib
joblib.dump(final_model, "model_by_mirza.pkl")
# Out:
# ['model_by_mirza.pkl']

# %% [markdown]
# ## You can test my model with your test data.
